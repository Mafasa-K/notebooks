# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision
import torchvision.transforms as transforms

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)


    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)  ## Come back here and apply F func
        return x


net = Net()

# %%
loss_func = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr = 1e-3, momentum = 0.9)

# %%
for epoch in range(10):

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = loss_func(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:
            print('[%d, %5d] loss: %.3f' %
                 (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0

print('Model Finished Training')
# Out:
# [1,  2000] loss: 1.207
# [1,  4000] loss: 1.214
# [1,  6000] loss: 1.186
# [1,  8000] loss: 1.181
# [1, 10000] loss: 1.174
# [1, 12000] loss: 1.176
# [2,  2000] loss: 1.079
# [2,  4000] loss: 1.119
# [2,  6000] loss: 1.121
# [2,  8000] loss: 1.115
# [2, 10000] loss: 1.109
# [2, 12000] loss: 1.107
# [3,  2000] loss: 1.035
# [3,  4000] loss: 1.020
# [3,  6000] loss: 1.038
# [3,  8000] loss: 1.051
# [3, 10000] loss: 1.039
# [3, 12000] loss: 1.047
# [4,  2000] loss: 0.951
# [4,  4000] loss: 0.996
# [4,  6000] loss: 0.991
# [4,  8000] loss: 1.006
# [4, 10000] loss: 0.998
# [4, 12000] loss: 0.980
# [5,  2000] loss: 0.909
# [5,  4000] loss: 0.926
# [5,  6000] loss: 0.941
# [5,  8000] loss: 0.937
# [5, 10000] loss: 0.948
# [5, 12000] loss: 0.958
# [6,  2000] loss: 0.855
# [6,  4000] loss: 0.876
# [6,  6000] loss: 0.904
# [6,  8000] loss: 0.892
# [6, 10000] loss: 0.923
# [6, 12000] loss: 0.921
# [7,  2000] loss: 0.816
# [7,  4000] loss: 0.833
# [7,  6000] loss: 0.865
# [7,  8000] loss: 0.860
# [7, 10000] loss: 0.880
# [7, 12000] loss: 0.902
# [8,  2000] loss: 0.791
# [8,  4000] loss: 0.804
# [8,  6000] loss: 0.821
# [8,  8000] loss: 0.850
# [8, 10000] loss: 0.847
# [8, 12000] loss: 0.873
# [9,  2000] loss: 0.741
# [9,  4000] loss: 0.776
# [9,  6000] loss: 0.813
# [9,  8000] loss: 0.810
# [9, 10000] loss: 0.834
# [9, 12000] loss: 0.849
# [10,  2000] loss: 0.704
# [10,  4000] loss: 0.764
# [10,  6000] loss: 0.781
# [10,  8000] loss: 0.786
# [10, 10000] loss: 0.802
# [10, 12000] loss: 0.822
# Model Finished Training

# %%
correct = 0
total = 0
accuracies = []
with torch.no_grad():
    for data in testloader:
        images,labels = data
        output = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        accuracies.append(100 * correct / total)

        print(f'Accuracy of the network on the test run {i+1}: {accuracy} %')
        
print(f'All recorded accuracies: {accuracies}')
# Out:
# Accuracy of the network on the test run 12500: 0.0 %
# Accuracy of the network on the test run 12500: 0.0 %
# Accuracy of the network on the test run 12500: 8.333333333333334 %
# Accuracy of the network on the test run 12500: 12.5 %
# Accuracy of the network on the test run 12500: 10.0 %
# Accuracy of the network on the test run 12500: 8.333333333333334 %
# Accuracy of the network on the test run 12500: 7.142857142857143 %
# Accuracy of the network on the test run 12500: 6.25 %
# Accuracy of the network on the test run 12500: 8.333333333333334 %
# Accuracy of the network on the test run 12500: 7.5 %
# Accuracy of the network on the test run 12500: 6.818181818181818 %
# Accuracy of the network on the test run 12500: 6.25 %
# Accuracy of the network on the test run 12500: 7.6923076923076925 %
# Accuracy of the network on the test run 12500: 8.928571428571429 %
# Accuracy of the network on the test run 12500: 8.333333333333334 %
# Accuracy of the network on the test run 12500: 7.8125 %
# Accuracy of the network on the test run 12500: 7.352941176470588 %
# Accuracy of the network on the test run 12500: 6.944444444444445 %
# Accuracy of the network on the test run 12500: 9.210526315789474 %
# Accuracy of the network on the test run 12500: 10.0 %
# Accuracy of the network on the test run 12500: 10.714285714285714 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 13.043478260869565 %
# Accuracy of the network on the test run 12500: 13.541666666666666 %
# Accuracy of the network on the test run 12500: 14.0 %
# Accuracy of the network on the test run 12500: 14.423076923076923 %
# Accuracy of the network on the test run 12500: 13.88888888888889 %
# Accuracy of the network on the test run 12500: 14.285714285714286 %
# Accuracy of the network on the test run 12500: 13.793103448275861 %
# Accuracy of the network on the test run 12500: 13.333333333333334 %
# Accuracy of the network on the test run 12500: 13.709677419354838 %
# Accuracy of the network on the test run 12500: 14.0625 %
# Accuracy of the network on the test run 12500: 13.636363636363637 %
# Accuracy of the network on the test run 12500: 13.970588235294118 %
# Accuracy of the network on the test run 12500: 13.571428571428571 %
# Accuracy of the network on the test run 12500: 13.88888888888889 %
# Accuracy of the network on the test run 12500: 14.18918918918919 %
# Accuracy of the network on the test run 12500: 13.81578947368421 %
# Accuracy of the network on the test run 12500: 14.102564102564102 %
# Accuracy of the network on the test run 12500: 13.75 %
# Accuracy of the network on the test run 12500: 13.414634146341463 %
# Accuracy of the network on the test run 12500: 13.69047619047619 %
# Accuracy of the network on the test run 12500: 13.372093023255815 %
# Accuracy of the network on the test run 12500: 13.068181818181818 %
# Accuracy of the network on the test run 12500: 12.777777777777779 %
# Accuracy of the network on the test run 12500: 13.043478260869565 %
# Accuracy of the network on the test run 12500: 12.76595744680851 %
# Accuracy of the network on the test run 12500: 13.020833333333334 %
# Accuracy of the network on the test run 12500: 12.755102040816327 %
# Accuracy of the network on the test run 12500: 13.5 %
# Accuracy of the network on the test run 12500: 13.235294117647058 %
# Accuracy of the network on the test run 12500: 13.461538461538462 %
# Accuracy of the network on the test run 12500: 13.20754716981132 %
# Accuracy of the network on the test run 12500: 12.962962962962964 %
# Accuracy of the network on the test run 12500: 12.727272727272727 %
# Accuracy of the network on the test run 12500: 12.5 %
# Accuracy of the network on the test run 12500: 12.280701754385966 %
# Accuracy of the network on the test run 12500: 12.068965517241379 %
# Accuracy of the network on the test run 12500: 11.864406779661017 %
# Accuracy of the network on the test run 12500: 11.666666666666666 %
# Accuracy of the network on the test run 12500: 11.475409836065573 %
# Accuracy of the network on the test run 12500: 11.290322580645162 %
# Accuracy of the network on the test run 12500: 11.11111111111111 %
# Accuracy of the network on the test run 12500: 10.9375 %
# Accuracy of the network on the test run 12500: 11.153846153846153 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 11.194029850746269 %
# Accuracy of the network on the test run 12500: 11.029411764705882 %
# Accuracy of the network on the test run 12500: 10.869565217391305 %
# Accuracy of the network on the test run 12500: 10.714285714285714 %
# Accuracy of the network on the test run 12500: 10.56338028169014 %
# Accuracy of the network on the test run 12500: 10.416666666666666 %
# Accuracy of the network on the test run 12500: 10.273972602739725 %
# Accuracy of the network on the test run 12500: 10.135135135135135 %
# Accuracy of the network on the test run 12500: 10.333333333333334 %
# Accuracy of the network on the test run 12500: 10.197368421052632 %
# Accuracy of the network on the test run 12500: 10.064935064935066 %
# Accuracy of the network on the test run 12500: 9.935897435897436 %
# Accuracy of the network on the test run 12500: 10.126582278481013 %
# Accuracy of the network on the test run 12500: 10.0 %
# Accuracy of the network on the test run 12500: 10.185185185185185 %
# Accuracy of the network on the test run 12500: 10.060975609756097 %
# Accuracy of the network on the test run 12500: 9.939759036144578 %
# Accuracy of the network on the test run 12500: 9.821428571428571 %
# Accuracy of the network on the test run 12500: 10.0 %
# Accuracy of the network on the test run 12500: 9.883720930232558 %
# Accuracy of the network on the test run 12500: 10.344827586206897 %
# Accuracy of the network on the test run 12500: 10.511363636363637 %
# Accuracy of the network on the test run 12500: 10.393258426966293 %
# Accuracy of the network on the test run 12500: 10.277777777777779 %
# Accuracy of the network on the test run 12500: 10.43956043956044 %
# Accuracy of the network on the test run 12500: 10.326086956521738 %
# Accuracy of the network on the test run 12500: 10.483870967741936 %
# Accuracy of the network on the test run 12500: 10.372340425531915 %
# Accuracy of the network on the test run 12500: 10.526315789473685 %
# Accuracy of the network on the test run 12500: 10.677083333333334 %
# Accuracy of the network on the test run 12500: 10.56701030927835 %
# Accuracy of the network on the test run 12500: 10.714285714285714 %
# Accuracy of the network on the test run 12500: 10.606060606060606 %
# Accuracy of the network on the test run 12500: 10.75 %
# Accuracy of the network on the test run 12500: 10.891089108910892 %
# Accuracy of the network on the test run 12500: 11.27450980392157 %
# Accuracy of the network on the test run 12500: 11.407766990291263 %
# Accuracy of the network on the test run 12500: 11.298076923076923 %
# Accuracy of the network on the test run 12500: 11.19047619047619 %
# Accuracy of the network on the test run 12500: 11.556603773584905 %
# Accuracy of the network on the test run 12500: 11.448598130841122 %
# Accuracy of the network on the test run 12500: 11.342592592592593 %
# Accuracy of the network on the test run 12500: 11.238532110091743 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 11.26126126126126 %
# Accuracy of the network on the test run 12500: 11.160714285714286 %
# Accuracy of the network on the test run 12500: 11.061946902654867 %
# Accuracy of the network on the test run 12500: 10.964912280701755 %
# Accuracy of the network on the test run 12500: 11.08695652173913 %
# Accuracy of the network on the test run 12500: 10.991379310344827 %
# Accuracy of the network on the test run 12500: 10.897435897435898 %
# Accuracy of the network on the test run 12500: 10.805084745762711 %
# Accuracy of the network on the test run 12500: 10.92436974789916 %
# Accuracy of the network on the test run 12500: 10.833333333333334 %
# Accuracy of the network on the test run 12500: 10.950413223140496 %
# Accuracy of the network on the test run 12500: 10.860655737704919 %
# Accuracy of the network on the test run 12500: 10.772357723577235 %
# Accuracy of the network on the test run 12500: 11.088709677419354 %
# Accuracy of the network on the test run 12500: 11.0 %
# Accuracy of the network on the test run 12500: 10.912698412698413 %
# Accuracy of the network on the test run 12500: 10.826771653543307 %
# Accuracy of the network on the test run 12500: 10.7421875 %
# Accuracy of the network on the test run 12500: 10.65891472868217 %
# Accuracy of the network on the test run 12500: 10.961538461538462 %
# Accuracy of the network on the test run 12500: 11.068702290076336 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 11.278195488721805 %
# Accuracy of the network on the test run 12500: 11.380597014925373 %
# Accuracy of the network on the test run 12500: 11.296296296296296 %
# Accuracy of the network on the test run 12500: 11.213235294117647 %
# Accuracy of the network on the test run 12500: 11.13138686131387 %
# Accuracy of the network on the test run 12500: 11.231884057971014 %
# Accuracy of the network on the test run 12500: 11.510791366906474 %
# Accuracy of the network on the test run 12500: 11.428571428571429 %
# Accuracy of the network on the test run 12500: 11.347517730496454 %
# Accuracy of the network on the test run 12500: 11.267605633802816 %
# Accuracy of the network on the test run 12500: 11.188811188811188 %
# Accuracy of the network on the test run 12500: 11.11111111111111 %
# Accuracy of the network on the test run 12500: 11.206896551724139 %
# Accuracy of the network on the test run 12500: 11.13013698630137 %
# Accuracy of the network on the test run 12500: 11.054421768707483 %
# Accuracy of the network on the test run 12500: 11.14864864864865 %
# Accuracy of the network on the test run 12500: 11.073825503355705 %
# Accuracy of the network on the test run 12500: 11.0 %
# Accuracy of the network on the test run 12500: 11.42384105960265 %
# Accuracy of the network on the test run 12500: 11.348684210526315 %
# Accuracy of the network on the test run 12500: 11.27450980392157 %
# Accuracy of the network on the test run 12500: 11.525974025974026 %
# Accuracy of the network on the test run 12500: 11.451612903225806 %
# Accuracy of the network on the test run 12500: 11.378205128205128 %
# Accuracy of the network on the test run 12500: 11.305732484076433 %
# Accuracy of the network on the test run 12500: 11.234177215189874 %
# Accuracy of the network on the test run 12500: 11.163522012578616 %
# Accuracy of the network on the test run 12500: 11.40625 %
# Accuracy of the network on the test run 12500: 11.490683229813664 %
# Accuracy of the network on the test run 12500: 11.419753086419753 %
# Accuracy of the network on the test run 12500: 11.503067484662576 %
# Accuracy of the network on the test run 12500: 11.432926829268293 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 11.295180722891565 %
# Accuracy of the network on the test run 12500: 11.22754491017964 %
# Accuracy of the network on the test run 12500: 11.160714285714286 %
# Accuracy of the network on the test run 12500: 11.094674556213018 %
# Accuracy of the network on the test run 12500: 11.176470588235293 %
# Accuracy of the network on the test run 12500: 11.257309941520468 %
# Accuracy of the network on the test run 12500: 11.19186046511628 %
# Accuracy of the network on the test run 12500: 11.127167630057803 %
# Accuracy of the network on the test run 12500: 11.063218390804598 %
# Accuracy of the network on the test run 12500: 11.142857142857142 %
# Accuracy of the network on the test run 12500: 11.221590909090908 %
# Accuracy of the network on the test run 12500: 11.158192090395481 %
# Accuracy of the network on the test run 12500: 11.376404494382022 %
# Accuracy of the network on the test run 12500: 11.452513966480447 %
# Accuracy of the network on the test run 12500: 11.38888888888889 %
# Accuracy of the network on the test run 12500: 11.32596685082873 %
# Accuracy of the network on the test run 12500: 11.401098901098901 %
# Accuracy of the network on the test run 12500: 11.475409836065573 %
# Accuracy of the network on the test run 12500: 11.41304347826087 %
# Accuracy of the network on the test run 12500: 11.35135135135135 %
# Accuracy of the network on the test run 12500: 11.424731182795698 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 11.436170212765957 %
# Accuracy of the network on the test run 12500: 11.375661375661375 %
# Accuracy of the network on the test run 12500: 11.31578947368421 %
# Accuracy of the network on the test run 12500: 11.256544502617801 %
# Accuracy of the network on the test run 12500: 11.197916666666666 %
# Accuracy of the network on the test run 12500: 11.139896373056995 %
# Accuracy of the network on the test run 12500: 11.211340206185566 %
# Accuracy of the network on the test run 12500: 11.282051282051283 %
# Accuracy of the network on the test run 12500: 11.224489795918368 %
# Accuracy of the network on the test run 12500: 11.16751269035533 %
# Accuracy of the network on the test run 12500: 11.11111111111111 %
# Accuracy of the network on the test run 12500: 11.055276381909549 %
# Accuracy of the network on the test run 12500: 11.0 %
# Accuracy of the network on the test run 12500: 10.945273631840797 %
# Accuracy of the network on the test run 12500: 10.891089108910892 %
# Accuracy of the network on the test run 12500: 10.83743842364532 %
# Accuracy of the network on the test run 12500: 11.029411764705882 %
# Accuracy of the network on the test run 12500: 11.097560975609756 %
# Accuracy of the network on the test run 12500: 11.28640776699029 %
# Accuracy of the network on the test run 12500: 11.231884057971014 %
# Accuracy of the network on the test run 12500: 11.177884615384615 %
# Accuracy of the network on the test run 12500: 11.124401913875598 %
# Accuracy of the network on the test run 12500: 11.071428571428571 %
# Accuracy of the network on the test run 12500: 11.018957345971565 %
# Accuracy of the network on the test run 12500: 10.966981132075471 %
# Accuracy of the network on the test run 12500: 10.915492957746478 %
# Accuracy of the network on the test run 12500: 11.098130841121495 %
# Accuracy of the network on the test run 12500: 11.162790697674419 %
# Accuracy of the network on the test run 12500: 11.11111111111111 %
# Accuracy of the network on the test run 12500: 11.059907834101383 %
# Accuracy of the network on the test run 12500: 11.009174311926605 %
# Accuracy of the network on the test run 12500: 11.073059360730594 %
# Accuracy of the network on the test run 12500: 11.022727272727273 %
# Accuracy of the network on the test run 12500: 11.085972850678733 %
# Accuracy of the network on the test run 12500: 11.14864864864865 %
# Accuracy of the network on the test run 12500: 11.09865470852018 %
# Accuracy of the network on the test run 12500: 11.049107142857142 %
# Accuracy of the network on the test run 12500: 11.0 %
# Accuracy of the network on the test run 12500: 10.951327433628318 %
# Accuracy of the network on the test run 12500: 11.013215859030836 %
# Accuracy of the network on the test run 12500: 11.074561403508772 %
# Accuracy of the network on the test run 12500: 11.135371179039302 %
# Accuracy of the network on the test run 12500: 11.08695652173913 %
# Accuracy of the network on the test run 12500: 11.03896103896104 %
# Accuracy of the network on the test run 12500: 11.099137931034482 %
# Accuracy of the network on the test run 12500: 11.051502145922747 %
# Accuracy of the network on the test run 12500: 11.004273504273504 %
# Accuracy of the network on the test run 12500: 11.170212765957446 %
# Accuracy of the network on the test run 12500: 11.122881355932204 %
# Accuracy of the network on the test run 12500: 11.181434599156118 %
# Accuracy of the network on the test run 12500: 11.134453781512605 %
# Accuracy of the network on the test run 12500: 11.087866108786612 %
# Accuracy of the network on the test run 12500: 11.145833333333334 %
# Accuracy of the network on the test run 12500: 11.099585062240664 %
# Accuracy of the network on the test run 12500: 11.053719008264462 %
# Accuracy of the network on the test run 12500: 11.008230452674898 %
# Accuracy of the network on the test run 12500: 10.96311475409836 %
# Accuracy of the network on the test run 12500: 10.918367346938776 %
# Accuracy of the network on the test run 12500: 10.975609756097562 %
# Accuracy of the network on the test run 12500: 10.931174089068826 %
# Accuracy of the network on the test run 12500: 10.887096774193548 %
# Accuracy of the network on the test run 12500: 10.943775100401606 %
# Accuracy of the network on the test run 12500: 11.1 %
# Accuracy of the network on the test run 12500: 11.055776892430279 %
# Accuracy of the network on the test run 12500: 11.21031746031746 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 11.318897637795276 %
# Accuracy of the network on the test run 12500: 11.372549019607844 %
# Accuracy of the network on the test run 12500: 11.42578125 %
# Accuracy of the network on the test run 12500: 11.575875486381323 %
# Accuracy of the network on the test run 12500: 11.531007751937985 %
# Accuracy of the network on the test run 12500: 11.486486486486486 %
# Accuracy of the network on the test run 12500: 11.442307692307692 %
# Accuracy of the network on the test run 12500: 11.494252873563218 %
# Accuracy of the network on the test run 12500: 11.641221374045802 %
# Accuracy of the network on the test run 12500: 11.596958174904943 %
# Accuracy of the network on the test run 12500: 11.553030303030303 %
# Accuracy of the network on the test run 12500: 11.60377358490566 %
# Accuracy of the network on the test run 12500: 11.56015037593985 %
# Accuracy of the network on the test run 12500: 11.51685393258427 %
# Accuracy of the network on the test run 12500: 11.473880597014926 %
# Accuracy of the network on the test run 12500: 11.524163568773234 %
# Accuracy of the network on the test run 12500: 11.574074074074074 %
# Accuracy of the network on the test run 12500: 11.531365313653136 %
# Accuracy of the network on the test run 12500: 11.488970588235293 %
# Accuracy of the network on the test run 12500: 11.63003663003663 %
# Accuracy of the network on the test run 12500: 11.587591240875913 %
# Accuracy of the network on the test run 12500: 11.636363636363637 %
# Accuracy of the network on the test run 12500: 11.594202898550725 %
# Accuracy of the network on the test run 12500: 11.552346570397113 %
# Accuracy of the network on the test run 12500: 11.600719424460431 %
# Accuracy of the network on the test run 12500: 11.559139784946236 %
# Accuracy of the network on the test run 12500: 11.607142857142858 %
# Accuracy of the network on the test run 12500: 11.565836298932384 %
# Accuracy of the network on the test run 12500: 11.613475177304965 %
# Accuracy of the network on the test run 12500: 11.57243816254417 %
# Accuracy of the network on the test run 12500: 11.53169014084507 %
# Accuracy of the network on the test run 12500: 11.578947368421053 %
# Accuracy of the network on the test run 12500: 11.538461538461538 %
# Accuracy of the network on the test run 12500: 11.498257839721255 %
# Accuracy of the network on the test run 12500: 11.458333333333334 %
# Accuracy of the network on the test run 12500: 11.418685121107266 %
# Accuracy of the network on the test run 12500: 11.46551724137931 %
# Accuracy of the network on the test run 12500: 11.512027491408935 %
# Accuracy of the network on the test run 12500: 11.558219178082192 %
# Accuracy of the network on the test run 12500: 11.518771331058021 %
# Accuracy of the network on the test run 12500: 11.479591836734693 %
# Accuracy of the network on the test run 12500: 11.440677966101696 %
# Accuracy of the network on the test run 12500: 11.402027027027026 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 11.325503355704697 %
# Accuracy of the network on the test run 12500: 11.37123745819398 %
# Accuracy of the network on the test run 12500: 11.333333333333334 %
# Accuracy of the network on the test run 12500: 11.378737541528238 %
# Accuracy of the network on the test run 12500: 11.341059602649006 %
# Accuracy of the network on the test run 12500: 11.386138613861386 %
# Accuracy of the network on the test run 12500: 11.348684210526315 %
# Accuracy of the network on the test run 12500: 11.39344262295082 %
# Accuracy of the network on the test run 12500: 11.437908496732026 %
# Accuracy of the network on the test run 12500: 11.400651465798045 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 11.326860841423947 %
# Accuracy of the network on the test run 12500: 11.290322580645162 %
# Accuracy of the network on the test run 12500: 11.334405144694534 %
# Accuracy of the network on the test run 12500: 11.298076923076923 %
# Accuracy of the network on the test run 12500: 11.261980830670927 %
# Accuracy of the network on the test run 12500: 11.226114649681529 %
# Accuracy of the network on the test run 12500: 11.26984126984127 %
# Accuracy of the network on the test run 12500: 11.313291139240507 %
# Accuracy of the network on the test run 12500: 11.435331230283913 %
# Accuracy of the network on the test run 12500: 11.477987421383649 %
# Accuracy of the network on the test run 12500: 11.442006269592477 %
# Accuracy of the network on the test run 12500: 11.484375 %
# Accuracy of the network on the test run 12500: 11.448598130841122 %
# Accuracy of the network on the test run 12500: 11.490683229813664 %
# Accuracy of the network on the test run 12500: 11.455108359133128 %
# Accuracy of the network on the test run 12500: 11.419753086419753 %
# Accuracy of the network on the test run 12500: 11.384615384615385 %
# Accuracy of the network on the test run 12500: 11.349693251533742 %
# Accuracy of the network on the test run 12500: 11.314984709480122 %
# Accuracy of the network on the test run 12500: 11.432926829268293 %
# Accuracy of the network on the test run 12500: 11.398176291793312 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 11.404833836858007 %
# Accuracy of the network on the test run 12500: 11.370481927710843 %
# Accuracy of the network on the test run 12500: 11.486486486486486 %
# Accuracy of the network on the test run 12500: 11.452095808383234 %
# Accuracy of the network on the test run 12500: 11.492537313432836 %
# Accuracy of the network on the test run 12500: 11.458333333333334 %
# Accuracy of the network on the test run 12500: 11.498516320474778 %
# Accuracy of the network on the test run 12500: 11.464497041420119 %
# Accuracy of the network on the test run 12500: 11.430678466076696 %
# Accuracy of the network on the test run 12500: 11.397058823529411 %
# Accuracy of the network on the test run 12500: 11.363636363636363 %
# Accuracy of the network on the test run 12500: 11.330409356725147 %
# Accuracy of the network on the test run 12500: 11.29737609329446 %
# Accuracy of the network on the test run 12500: 11.26453488372093 %
# Accuracy of the network on the test run 12500: 11.231884057971014 %
# Accuracy of the network on the test run 12500: 11.271676300578035 %
# Accuracy of the network on the test run 12500: 11.311239193083573 %
# Accuracy of the network on the test run 12500: 11.350574712643677 %
# Accuracy of the network on the test run 12500: 11.318051575931232 %
# Accuracy of the network on the test run 12500: 11.285714285714286 %
# Accuracy of the network on the test run 12500: 11.253561253561253 %
# Accuracy of the network on the test run 12500: 11.292613636363637 %
# Accuracy of the network on the test run 12500: 11.260623229461757 %
# Accuracy of the network on the test run 12500: 11.228813559322035 %
# Accuracy of the network on the test run 12500: 11.267605633802816 %
# Accuracy of the network on the test run 12500: 11.235955056179776 %
# Accuracy of the network on the test run 12500: 11.204481792717086 %
# Accuracy of the network on the test run 12500: 11.1731843575419 %
# Accuracy of the network on the test run 12500: 11.211699164345404 %
# Accuracy of the network on the test run 12500: 11.180555555555555 %
# Accuracy of the network on the test run 12500: 11.149584487534627 %
# Accuracy of the network on the test run 12500: 11.256906077348066 %
# Accuracy of the network on the test run 12500: 11.225895316804408 %
# Accuracy of the network on the test run 12500: 11.263736263736265 %
# Accuracy of the network on the test run 12500: 11.301369863013699 %
# Accuracy of the network on the test run 12500: 11.270491803278688 %
# Accuracy of the network on the test run 12500: 11.239782016348775 %
# Accuracy of the network on the test run 12500: 11.277173913043478 %
# Accuracy of the network on the test run 12500: 11.246612466124661 %
# Accuracy of the network on the test run 12500: 11.216216216216216 %
# Accuracy of the network on the test run 12500: 11.185983827493262 %
# Accuracy of the network on the test run 12500: 11.155913978494624 %
# Accuracy of the network on the test run 12500: 11.193029490616622 %
# Accuracy of the network on the test run 12500: 11.163101604278076 %
# Accuracy of the network on the test run 12500: 11.2 %
# Accuracy of the network on the test run 12500: 11.170212765957446 %
# Accuracy of the network on the test run 12500: 11.140583554376658 %
# Accuracy of the network on the test run 12500: 11.177248677248677 %
# Accuracy of the network on the test run 12500: 11.279683377308707 %
# Accuracy of the network on the test run 12500: 11.25 %
# Accuracy of the network on the test run 12500: 11.220472440944881 %
# Accuracy of the network on the test run 12500: 11.19109947643979 %
# Accuracy of the network on the test run 12500: 11.161879895561357 %
# Accuracy of the network on the test run 12500: 11.197916666666666 %
# Accuracy of the network on the test run 12500: 11.168831168831169 %
# Accuracy of the network on the test run 12500: 11.204663212435234 %
# Accuracy of the network on the test run 12500: 11.175710594315245 %
# Accuracy of the network on the test run 12500: 11.146907216494846 %
# Accuracy of the network on the test run 12500: 11.118251928020566 %
# Accuracy of the network on the test run 12500: 11.153846153846153 %
# Accuracy of the network on the test run 12500: 11.18925831202046 %
# Accuracy of the network on the test run 12500: 11.160714285714286 %
# Accuracy of the network on the test run 12500: 11.132315521628499 %
# Accuracy of the network on the test run 12500: 11.16751269035533 %
# Accuracy of the network on the test run 12500: 11.20253164556962 %
# Accuracy of the network on the test run 12500: 11.174242424242424 %
# Accuracy of the network on the test run 12500: 11.146095717884132 %
# Accuracy of the network on the test run 12500: 11.118090452261306 %
# Accuracy of the network on the test run 12500: 11.090225563909774 %
# Accuracy of the network on the test run 12500: 11.0625 %
# Accuracy of the network on the test run 12500: 11.097256857855362 %
# Accuracy of the network on the test run 12500: 11.069651741293532 %
# Accuracy of the network on the test run 12500: 11.042183622828784 %
# Accuracy of the network on the test run 12500: 11.014851485148515 %
# Accuracy of the network on the test run 12500: 10.987654320987655 %
# Accuracy of the network on the test run 12500: 10.960591133004925 %
# Accuracy of the network on the test run 12500: 10.933660933660933 %
# Accuracy of the network on the test run 12500: 10.906862745098039 %
# Accuracy of the network on the test run 12500: 10.941320293398533 %
# Accuracy of the network on the test run 12500: 10.975609756097562 %
# Accuracy of the network on the test run 12500: 10.94890510948905 %
# Accuracy of the network on the test run 12500: 10.983009708737864 %
# Accuracy of the network on the test run 12500: 11.077481840193705 %
# Accuracy of the network on the test run 12500: 11.11111111111111 %
# Accuracy of the network on the test run 12500: 11.204819277108435 %
# Accuracy of the network on the test run 12500: 11.177884615384615 %
# Accuracy of the network on the test run 12500: 11.151079136690647 %
# Accuracy of the network on the test run 12500: 11.18421052631579 %
# Accuracy of the network on the test run 12500: 11.157517899761336 %
# Accuracy of the network on the test run 12500: 11.19047619047619 %
# Accuracy of the network on the test run 12500: 11.282660332541568 %
# Accuracy of the network on the test run 12500: 11.374407582938389 %
# Accuracy of the network on the test run 12500: 11.40661938534279 %
# Accuracy of the network on the test run 12500: 11.43867924528302 %
# Accuracy of the network on the test run 12500: 11.411764705882353 %
# Accuracy of the network on the test run 12500: 11.443661971830986 %
# Accuracy of the network on the test run 12500: 11.416861826697891 %
# Accuracy of the network on the test run 12500: 11.39018691588785 %
# Accuracy of the network on the test run 12500: 11.421911421911421 %
# Accuracy of the network on the test run 12500: 11.453488372093023 %
# Accuracy of the network on the test run 12500: 11.42691415313225 %
# Accuracy of the network on the test run 12500: 11.458333333333334 %
# Accuracy of the network on the test run 12500: 11.431870669745958 %
# Accuracy of the network on the test run 12500: 11.40552995391705 %
# Accuracy of the network on the test run 12500: 11.379310344827585 %
# Accuracy of the network on the test run 12500: 11.353211009174313 %
# Accuracy of the network on the test run 12500: 11.384439359267734 %
# Accuracy of the network on the test run 12500: 11.358447488584474 %
# Accuracy of the network on the test run 12500: 11.33257403189066 %
# Accuracy of the network on the test run 12500: 11.306818181818182 %
# Accuracy of the network on the test run 12500: 11.281179138321995 %
# Accuracy of the network on the test run 12500: 11.255656108597286 %
# Accuracy of the network on the test run 12500: 11.230248306997742 %
# Accuracy of the network on the test run 12500: 11.317567567567568 %
# Accuracy of the network on the test run 12500: 11.292134831460674 %
# Accuracy of the network on the test run 12500: 11.32286995515695 %
# Accuracy of the network on the test run 12500: 11.297539149888143 %
# Accuracy of the network on the test run 12500: 11.272321428571429 %
# Accuracy of the network on the test run 12500: 11.302895322939866 %
# Accuracy of the network on the test run 12500: 11.277777777777779 %
# Accuracy of the network on the test run 12500: 11.252771618625276 %
# Accuracy of the network on the test run 12500: 11.22787610619469 %
# Accuracy of the network on the test run 12500: 11.20309050772627 %
# Accuracy of the network on the test run 12500: 11.178414096916299 %
# Accuracy of the network on the test run 12500: 11.153846153846153 %
# Accuracy of the network on the test run 12500: 11.18421052631579 %
# Accuracy of the network on the test run 12500: 11.159737417943107 %
# Accuracy of the network on the test run 12500: 11.135371179039302 %
# Accuracy of the network on the test run 12500: 11.11111111111111 %
# Accuracy of the network on the test run 12500: 11.08695652173913 %
# Accuracy of the network on the test run 12500: 11.171366594360087 %
# Accuracy of the network on the test run 12500: 11.147186147186147 %
# Accuracy of the network on the test run 12500: 11.123110151187905 %
# Accuracy of the network on the test run 12500: 11.099137931034482 %
# Accuracy of the network on the test run 12500: 11.182795698924732 %
# Accuracy of the network on the test run 12500: 11.21244635193133 %
# Accuracy of the network on the test run 12500: 11.188436830835117 %
# Accuracy of the network on the test run 12500: 11.164529914529915 %
# Accuracy of the network on the test run 12500: 11.140724946695096 %
# Accuracy of the network on the test run 12500: 11.117021276595745 %
# Accuracy of the network on the test run 12500: 11.093418259023355 %
# Accuracy of the network on the test run 12500: 11.122881355932204 %
# Accuracy of the network on the test run 12500: 11.152219873150106 %
# Accuracy of the network on the test run 12500: 11.181434599156118 %
# Accuracy of the network on the test run 12500: 11.210526315789474 %
# Accuracy of the network on the test run 12500: 11.344537815126051 %
# Accuracy of the network on the test run 12500: 11.320754716981131 %
# Accuracy of the network on the test run 12500: 11.297071129707113 %
# Accuracy of the network on the test run 12500: 11.273486430062631 %
# Accuracy of the network on the test run 12500: 11.25 %
# Accuracy of the network on the test run 12500: 11.226611226611226 %
# Accuracy of the network on the test run 12500: 11.255186721991702 %
# Accuracy of the network on the test run 12500: 11.231884057971014 %
# Accuracy of the network on the test run 12500: 11.208677685950413 %
# Accuracy of the network on the test run 12500: 11.185567010309278 %
# Accuracy of the network on the test run 12500: 11.213991769547325 %
# Accuracy of the network on the test run 12500: 11.190965092402465 %
# Accuracy of the network on the test run 12500: 11.168032786885245 %
# Accuracy of the network on the test run 12500: 11.14519427402863 %
# Accuracy of the network on the test run 12500: 11.122448979591837 %
# Accuracy of the network on the test run 12500: 11.09979633401222 %
# Accuracy of the network on the test run 12500: 11.077235772357724 %
# Accuracy of the network on the test run 12500: 11.105476673427992 %
# Accuracy of the network on the test run 12500: 11.082995951417004 %
# Accuracy of the network on the test run 12500: 11.11111111111111 %
# Accuracy of the network on the test run 12500: 11.139112903225806 %
# Accuracy of the network on the test run 12500: 11.116700201207243 %
# Accuracy of the network on the test run 12500: 11.094377510040161 %
# Accuracy of the network on the test run 12500: 11.072144288577155 %
# Accuracy of the network on the test run 12500: 11.05 %
# Accuracy of the network on the test run 12500: 11.077844311377245 %
# Accuracy of the network on the test run 12500: 11.155378486055778 %
# Accuracy of the network on the test run 12500: 11.133200795228628 %
# Accuracy of the network on the test run 12500: 11.11111111111111 %
# Accuracy of the network on the test run 12500: 11.138613861386139 %
# Accuracy of the network on the test run 12500: 11.116600790513834 %
# Accuracy of the network on the test run 12500: 11.094674556213018 %
# Accuracy of the network on the test run 12500: 11.07283464566929 %
# Accuracy of the network on the test run 12500: 11.051080550098233 %
# Accuracy of the network on the test run 12500: 11.127450980392156 %
# Accuracy of the network on the test run 12500: 11.154598825831702 %
# Accuracy of the network on the test run 12500: 11.1328125 %
# Accuracy of the network on the test run 12500: 11.159844054580896 %
# Accuracy of the network on the test run 12500: 11.186770428015564 %
# Accuracy of the network on the test run 12500: 11.262135922330097 %
# Accuracy of the network on the test run 12500: 11.28875968992248 %
# Accuracy of the network on the test run 12500: 11.315280464216634 %
# Accuracy of the network on the test run 12500: 11.293436293436294 %
# Accuracy of the network on the test run 12500: 11.271676300578035 %
# Accuracy of the network on the test run 12500: 11.25 %
# Accuracy of the network on the test run 12500: 11.228406909788868 %
# Accuracy of the network on the test run 12500: 11.206896551724139 %
# Accuracy of the network on the test run 12500: 11.18546845124283 %
# Accuracy of the network on the test run 12500: 11.164122137404581 %
# Accuracy of the network on the test run 12500: 11.19047619047619 %
# Accuracy of the network on the test run 12500: 11.216730038022813 %
# Accuracy of the network on the test run 12500: 11.195445920303605 %
# Accuracy of the network on the test run 12500: 11.221590909090908 %
# Accuracy of the network on the test run 12500: 11.200378071833649 %
# Accuracy of the network on the test run 12500: 11.179245283018869 %
# Accuracy of the network on the test run 12500: 11.20527306967985 %
# Accuracy of the network on the test run 12500: 11.18421052631579 %
# Accuracy of the network on the test run 12500: 11.210131332082552 %
# Accuracy of the network on the test run 12500: 11.235955056179776 %
# Accuracy of the network on the test run 12500: 11.261682242990654 %
# Accuracy of the network on the test run 12500: 11.240671641791044 %
# Accuracy of the network on the test run 12500: 11.219739292364991 %
# Accuracy of the network on the test run 12500: 11.198884758364311 %
# Accuracy of the network on the test run 12500: 11.178107606679035 %
# Accuracy of the network on the test run 12500: 11.25 %
# Accuracy of the network on the test run 12500: 11.275415896487985 %
# Accuracy of the network on the test run 12500: 11.300738007380074 %
# Accuracy of the network on the test run 12500: 11.279926335174954 %
# Accuracy of the network on the test run 12500: 11.259191176470589 %
# Accuracy of the network on the test run 12500: 11.238532110091743 %
# Accuracy of the network on the test run 12500: 11.217948717948717 %
# Accuracy of the network on the test run 12500: 11.19744058500914 %
# Accuracy of the network on the test run 12500: 11.177007299270073 %
# Accuracy of the network on the test run 12500: 11.156648451730419 %
# Accuracy of the network on the test run 12500: 11.181818181818182 %
# Accuracy of the network on the test run 12500: 11.206896551724139 %
# Accuracy of the network on the test run 12500: 11.231884057971014 %
# Accuracy of the network on the test run 12500: 11.211573236889693 %
# Accuracy of the network on the test run 12500: 11.191335740072201 %
# Accuracy of the network on the test run 12500: 11.17117117117117 %
# Accuracy of the network on the test run 12500: 11.196043165467627 %
# Accuracy of the network on the test run 12500: 11.220825852782765 %
# Accuracy of the network on the test run 12500: 11.200716845878135 %
# Accuracy of the network on the test run 12500: 11.180679785330948 %
# Accuracy of the network on the test run 12500: 11.160714285714286 %
# Accuracy of the network on the test run 12500: 11.140819964349376 %
# Accuracy of the network on the test run 12500: 11.12099644128114 %
# Accuracy of the network on the test run 12500: 11.101243339253996 %
# Accuracy of the network on the test run 12500: 11.081560283687944 %
# Accuracy of the network on the test run 12500: 11.061946902654867 %
# Accuracy of the network on the test run 12500: 11.042402826855124 %
# Accuracy of the network on the test run 12500: 11.022927689594356 %
# Accuracy of the network on the test run 12500: 11.003521126760564 %
# Accuracy of the network on the test run 12500: 11.028119507908611 %
# Accuracy of the network on the test run 12500: 11.052631578947368 %
# Accuracy of the network on the test run 12500: 11.07705779334501 %
# Accuracy of the network on the test run 12500: 11.101398601398602 %
# Accuracy of the network on the test run 12500: 11.082024432809773 %
# Accuracy of the network on the test run 12500: 11.106271777003485 %
# Accuracy of the network on the test run 12500: 11.130434782608695 %
# Accuracy of the network on the test run 12500: 11.15451388888889 %
# Accuracy of the network on the test run 12500: 11.135181975736568 %
# Accuracy of the network on the test run 12500: 11.115916955017301 %
# Accuracy of the network on the test run 12500: 11.096718480138168 %
# Accuracy of the network on the test run 12500: 11.120689655172415 %
# Accuracy of the network on the test run 12500: 11.187607573149743 %
# Accuracy of the network on the test run 12500: 11.168384879725085 %
# Accuracy of the network on the test run 12500: 11.192109777015437 %
# Accuracy of the network on the test run 12500: 11.172945205479452 %
# Accuracy of the network on the test run 12500: 11.153846153846153 %
# Accuracy of the network on the test run 12500: 11.134812286689419 %
# Accuracy of the network on the test run 12500: 11.158432708688245 %
# Accuracy of the network on the test run 12500: 11.181972789115646 %
# Accuracy of the network on the test run 12500: 11.162988115449915 %
# Accuracy of the network on the test run 12500: 11.186440677966102 %
# Accuracy of the network on the test run 12500: 11.16751269035533 %
# Accuracy of the network on the test run 12500: 11.14864864864865 %
# Accuracy of the network on the test run 12500: 11.172006745362562 %
# Accuracy of the network on the test run 12500: 11.153198653198654 %
# Accuracy of the network on the test run 12500: 11.134453781512605 %
# Accuracy of the network on the test run 12500: 11.199664429530202 %
# Accuracy of the network on the test run 12500: 11.180904522613066 %
# Accuracy of the network on the test run 12500: 11.16220735785953 %
# Accuracy of the network on the test run 12500: 11.143572621035059 %
# Accuracy of the network on the test run 12500: 11.208333333333334 %
# Accuracy of the network on the test run 12500: 11.189683860232945 %
# Accuracy of the network on the test run 12500: 11.17109634551495 %
# Accuracy of the network on the test run 12500: 11.15257048092869 %
# Accuracy of the network on the test run 12500: 11.1341059602649 %
# Accuracy of the network on the test run 12500: 11.115702479338843 %
# Accuracy of the network on the test run 12500: 11.138613861386139 %
# Accuracy of the network on the test run 12500: 11.161449752883032 %
# Accuracy of the network on the test run 12500: 11.18421052631579 %
# Accuracy of the network on the test run 12500: 11.206896551724139 %
# Accuracy of the network on the test run 12500: 11.188524590163935 %
# Accuracy of the network on the test run 12500: 11.170212765957446 %
# Accuracy of the network on the test run 12500: 11.151960784313726 %
# Accuracy of the network on the test run 12500: 11.174551386623165 %
# Accuracy of the network on the test run 12500: 11.156351791530945 %
# Accuracy of the network on the test run 12500: 11.178861788617887 %
# Accuracy of the network on the test run 12500: 11.160714285714286 %
# Accuracy of the network on the test run 12500: 11.142625607779578 %
# Accuracy of the network on the test run 12500: 11.16504854368932 %
# Accuracy of the network on the test run 12500: 11.147011308562197 %
# Accuracy of the network on the test run 12500: 11.169354838709678 %
# Accuracy of the network on the test run 12500: 11.191626409017713 %
# Accuracy of the network on the test run 12500: 11.17363344051447 %
# Accuracy of the network on the test run 12500: 11.195826645264848 %
# Accuracy of the network on the test run 12500: 11.217948717948717 %
# Accuracy of the network on the test run 12500: 11.2 %
# Accuracy of the network on the test run 12500: 11.222044728434504 %
# Accuracy of the network on the test run 12500: 11.20414673046252 %
# Accuracy of the network on the test run 12500: 11.226114649681529 %
# Accuracy of the network on the test run 12500: 11.208267090620032 %
# Accuracy of the network on the test run 12500: 11.19047619047619 %
# Accuracy of the network on the test run 12500: 11.172741679873218 %
# Accuracy of the network on the test run 12500: 11.234177215189874 %
# Accuracy of the network on the test run 12500: 11.216429699842022 %
# Accuracy of the network on the test run 12500: 11.198738170347003 %
# Accuracy of the network on the test run 12500: 11.220472440944881 %
# Accuracy of the network on the test run 12500: 11.202830188679245 %
# Accuracy of the network on the test run 12500: 11.185243328100471 %
# Accuracy of the network on the test run 12500: 11.16771159874608 %
# Accuracy of the network on the test run 12500: 11.150234741784038 %
# Accuracy of the network on the test run 12500: 11.1328125 %
# Accuracy of the network on the test run 12500: 11.11544461778471 %
# Accuracy of the network on the test run 12500: 11.098130841121495 %
# Accuracy of the network on the test run 12500: 11.119751166407465 %
# Accuracy of the network on the test run 12500: 11.141304347826088 %
# Accuracy of the network on the test run 12500: 11.162790697674419 %
# Accuracy of the network on the test run 12500: 11.145510835913313 %
# Accuracy of the network on the test run 12500: 11.128284389489954 %
# Accuracy of the network on the test run 12500: 11.149691358024691 %
# Accuracy of the network on the test run 12500: 11.171032357473035 %
# Accuracy of the network on the test run 12500: 11.153846153846153 %
# Accuracy of the network on the test run 12500: 11.175115207373272 %
# Accuracy of the network on the test run 12500: 11.196319018404909 %
# Accuracy of the network on the test run 12500: 11.217457886676875 %
# Accuracy of the network on the test run 12500: 11.238532110091743 %
# Accuracy of the network on the test run 12500: 11.221374045801527 %
# Accuracy of the network on the test run 12500: 11.242378048780488 %
# Accuracy of the network on the test run 12500: 11.263318112633181 %
# Accuracy of the network on the test run 12500: 11.246200607902736 %
# Accuracy of the network on the test run 12500: 11.229135053110774 %
# Accuracy of the network on the test run 12500: 11.212121212121213 %
# Accuracy of the network on the test run 12500: 11.195158850226928 %
# Accuracy of the network on the test run 12500: 11.216012084592146 %
# Accuracy of the network on the test run 12500: 11.199095022624434 %
# Accuracy of the network on the test run 12500: 11.18222891566265 %
# Accuracy of the network on the test run 12500: 11.165413533834586 %
# Accuracy of the network on the test run 12500: 11.14864864864865 %
# Accuracy of the network on the test run 12500: 11.131934032983509 %
# Accuracy of the network on the test run 12500: 11.115269461077844 %
# Accuracy of the network on the test run 12500: 11.136023916292974 %
# Accuracy of the network on the test run 12500: 11.156716417910447 %
# Accuracy of the network on the test run 12500: 11.140089418777944 %
# Accuracy of the network on the test run 12500: 11.160714285714286 %
# Accuracy of the network on the test run 12500: 11.181277860326894 %
# Accuracy of the network on the test run 12500: 11.201780415430267 %
# Accuracy of the network on the test run 12500: 11.185185185185185 %
# Accuracy of the network on the test run 12500: 11.168639053254438 %
# Accuracy of the network on the test run 12500: 11.152141802067947 %
# Accuracy of the network on the test run 12500: 11.135693215339233 %
# Accuracy of the network on the test run 12500: 11.119293078055964 %
# Accuracy of the network on the test run 12500: 11.102941176470589 %
# Accuracy of the network on the test run 12500: 11.086637298091043 %
# Accuracy of the network on the test run 12500: 11.070381231671554 %
# Accuracy of the network on the test run 12500: 11.09077598828697 %
# Accuracy of the network on the test run 12500: 11.074561403508772 %
# Accuracy of the network on the test run 12500: 11.094890510948906 %
# Accuracy of the network on the test run 12500: 11.078717201166182 %
# Accuracy of the network on the test run 12500: 11.06259097525473 %
# Accuracy of the network on the test run 12500: 11.046511627906977 %
# Accuracy of the network on the test run 12500: 11.030478955007258 %
# Accuracy of the network on the test run 12500: 11.014492753623188 %
# Accuracy of the network on the test run 12500: 10.998552821997105 %
# Accuracy of the network on the test run 12500: 10.982658959537572 %
# Accuracy of the network on the test run 12500: 10.966810966810966 %
# Accuracy of the network on the test run 12500: 10.951008645533141 %
# Accuracy of the network on the test run 12500: 10.971223021582734 %
# Accuracy of the network on the test run 12500: 10.991379310344827 %
# Accuracy of the network on the test run 12500: 10.975609756097562 %
# Accuracy of the network on the test run 12500: 10.959885386819485 %
# Accuracy of the network on the test run 12500: 10.97997138769671 %
# Accuracy of the network on the test run 12500: 11.0 %
# Accuracy of the network on the test run 12500: 11.01997146932953 %
# Accuracy of the network on the test run 12500: 11.004273504273504 %
# Accuracy of the network on the test run 12500: 10.988620199146515 %
# Accuracy of the network on the test run 12500: 10.973011363636363 %
# Accuracy of the network on the test run 12500: 10.957446808510639 %
# Accuracy of the network on the test run 12500: 10.941926345609065 %
# Accuracy of the network on the test run 12500: 10.926449787835926 %
# Accuracy of the network on the test run 12500: 10.911016949152541 %
# Accuracy of the network on the test run 12500: 10.895627644569817 %
# Accuracy of the network on the test run 12500: 10.880281690140846 %
# Accuracy of the network on the test run 12500: 10.864978902953586 %
# Accuracy of the network on the test run 12500: 10.919943820224718 %
# Accuracy of the network on the test run 12500: 10.904628330995793 %
# Accuracy of the network on the test run 12500: 10.88935574229692 %
# ...
# Accuracy of the network on the test run 12500: 9.743755383290267 %
# Accuracy of the network on the test run 12500: 9.771846749892381 %
# Accuracy of the network on the test run 12500: 9.767641996557659 %
# Accuracy of the network on the test run 12500: 9.774193548387096 %
# Accuracy of the network on the test run 12500: 9.769991401547722 %
# Accuracy of the network on the test run 12500: 9.776536312849162 %
# Accuracy of the network on the test run 12500: 9.78307560137457 %
# Accuracy of the network on the test run 12500: 9.778875053671104 %
# Accuracy of the network on the test run 12500: 9.774678111587983 %
# Accuracy of the network on the test run 12500: 9.77048477048477 %
# Accuracy of the network on the test run 12500: 9.777015437392796 %
# Accuracy of the network on the test run 12500: 9.77282468924132 %
# Accuracy of the network on the test run 12500: 9.768637532133676 %
# Accuracy of the network on the test run 12500: 9.775160599571734 %
# Accuracy of the network on the test run 12500: 9.781678082191782 %
# Accuracy of the network on the test run 12500: 9.78818998716303 %
# Accuracy of the network on the test run 12500: 9.784003421727972 %
# Accuracy of the network on the test run 12500: 9.80119709277469 %
# Accuracy of the network on the test run 12500: 9.797008547008547 %
# Accuracy of the network on the test run 12500: 9.792823579666809 %
# Accuracy of the network on the test run 12500: 9.78864218616567 %
# Accuracy of the network on the test run 12500: 9.805804524114384 %
# Accuracy of the network on the test run 12500: 9.801621160409557 %
# Accuracy of the network on the test run 12500: 9.797441364605543 %
# Accuracy of the network on the test run 12500: 9.793265132139812 %
# Accuracy of the network on the test run 12500: 9.789092458457606 %
# Accuracy of the network on the test run 12500: 9.784923339011925 %
# Accuracy of the network on the test run 12500: 9.780757769263516 %
# Accuracy of the network on the test run 12500: 9.77659574468085 %
# Accuracy of the network on the test run 12500: 9.77243726074011 %
# Accuracy of the network on the test run 12500: 9.76828231292517 %
# Accuracy of the network on the test run 12500: 9.764130896727583 %
# Accuracy of the network on the test run 12500: 9.770603228547154 %
# Accuracy of the network on the test run 12500: 9.766454352441613 %
# Accuracy of the network on the test run 12500: 9.762308998302208 %
# Accuracy of the network on the test run 12500: 9.75816716164616 %
# Accuracy of the network on the test run 12500: 9.754028837998304 %
# Accuracy of the network on the test run 12500: 9.749894022891056 %
# Accuracy of the network on the test run 12500: 9.745762711864407 %
# Accuracy of the network on the test run 12500: 9.752223634053367 %
# Accuracy of the network on the test run 12500: 9.74809483488569 %
# Accuracy of the network on the test run 12500: 9.754549301735082 %
# Accuracy of the network on the test run 12500: 9.750423011844331 %
# Accuracy of the network on the test run 12500: 9.746300211416491 %
# Accuracy of the network on the test run 12500: 9.74218089602705 %
# Accuracy of the network on the test run 12500: 9.748626953950147 %
# Accuracy of the network on the test run 12500: 9.744510135135135 %
# Accuracy of the network on the test run 12500: 9.750949767834529 %
# Accuracy of the network on the test run 12500: 9.767932489451477 %
# Accuracy of the network on the test run 12500: 9.774356811471952 %
# Accuracy of the network on the test run 12500: 9.770236087689714 %
# Accuracy of the network on the test run 12500: 9.776654024441635 %
# Accuracy of the network on the test run 12500: 9.772535804549284 %
# Accuracy of the network on the test run 12500: 9.76842105263158 %
# Accuracy of the network on the test run 12500: 9.764309764309765 %
# Accuracy of the network on the test run 12500: 9.760201935212452 %
# Accuracy of the network on the test run 12500: 9.766610597140454 %
# Accuracy of the network on the test run 12500: 9.762505254308532 %
# Accuracy of the network on the test run 12500: 9.758403361344538 %
# Accuracy of the network on the test run 12500: 9.754304913901722 %
# Accuracy of the network on the test run 12500: 9.750209907640638 %
# Accuracy of the network on the test run 12500: 9.746118338229122 %
# Accuracy of the network on the test run 12500: 9.75251677852349 %
# Accuracy of the network on the test run 12500: 9.748427672955975 %
# Accuracy of the network on the test run 12500: 9.744341994970663 %
# Accuracy of the network on the test run 12500: 9.74025974025974 %
# Accuracy of the network on the test run 12500: 9.736180904522612 %
# Accuracy of the network on the test run 12500: 9.732105483465885 %
# Accuracy of the network on the test run 12500: 9.748953974895397 %
# Accuracy of the network on the test run 12500: 9.744876620660811 %
# Accuracy of the network on the test run 12500: 9.740802675585284 %
# Accuracy of the network on the test run 12500: 9.747179272879231 %
# Accuracy of the network on the test run 12500: 9.753550543024227 %
# Accuracy of the network on the test run 12500: 9.749478079331942 %
# Accuracy of the network on the test run 12500: 9.745409015025041 %
# Accuracy of the network on the test run 12500: 9.741343345848978 %
# Accuracy of the network on the test run 12500: 9.7581317764804 %
# Accuracy of the network on the test run 12500: 9.754064193413923 %
# Accuracy of the network on the test run 12500: 9.75 %
# Accuracy of the network on the test run 12500: 9.7667638483965 %
# Accuracy of the network on the test run 12500: 9.783513738551207 %
# Accuracy of the network on the test run 12500: 9.789846025801081 %
# Accuracy of the network on the test run 12500: 9.785773710482529 %
# Accuracy of the network on the test run 12500: 9.792099792099792 %
# Accuracy of the network on the test run 12500: 9.788029925187033 %
# Accuracy of the network on the test run 12500: 9.783963439966763 %
# Accuracy of the network on the test run 12500: 9.779900332225914 %
# Accuracy of the network on the test run 12500: 9.775840597758407 %
# Accuracy of the network on the test run 12500: 9.782157676348548 %
# Accuracy of the network on the test run 12500: 9.78846951472418 %
# Accuracy of the network on the test run 12500: 9.78441127694859 %
# Accuracy of the network on the test run 12500: 9.790716949854952 %
# Accuracy of the network on the test run 12500: 9.7970173985087 %
# Accuracy of the network on the test run 12500: 9.803312629399587 %
# Accuracy of the network on the test run 12500: 9.809602649006623 %
# Accuracy of the network on the test run 12500: 9.805544062887877 %
# Accuracy of the network on the test run 12500: 9.801488833746898 %
# Accuracy of the network on the test run 12500: 9.797436957420421 %
# Accuracy of the network on the test run 12500: 9.793388429752065 %
# Accuracy of the network on the test run 12500: 9.79966955803387 %
# Accuracy of the network on the test run 12500: 9.795623451692816 %
# Accuracy of the network on the test run 12500: 9.791580685101115 %
# Accuracy of the network on the test run 12500: 9.787541254125413 %
# Accuracy of the network on the test run 12500: 9.783505154639176 %
# Accuracy of the network on the test run 12500: 9.779472382522671 %
# Accuracy of the network on the test run 12500: 9.775442933662958 %
# Accuracy of the network on the test run 12500: 9.771416803953871 %
# Accuracy of the network on the test run 12500: 9.767393989296007 %
# Accuracy of the network on the test run 12500: 9.77366255144033 %
# Accuracy of the network on the test run 12500: 9.779925956396545 %
# Accuracy of the network on the test run 12500: 9.775904605263158 %
# Accuracy of the network on the test run 12500: 9.771886559802713 %
# Accuracy of the network on the test run 12500: 9.767871815940838 %
# Accuracy of the network on the test run 12500: 9.784394250513348 %
# Accuracy of the network on the test run 12500: 9.79064039408867 %
# Accuracy of the network on the test run 12500: 9.786622897004515 %
# Accuracy of the network on the test run 12500: 9.782608695652174 %
# Accuracy of the network on the test run 12500: 9.77859778597786 %
# Accuracy of the network on the test run 12500: 9.774590163934427 %
# Accuracy of the network on the test run 12500: 9.780827529700943 %
# Accuracy of the network on the test run 12500: 9.787059787059787 %
# Accuracy of the network on the test run 12500: 9.78305362259517 %
# Accuracy of the network on the test run 12500: 9.779050736497545 %
# Accuracy of the network on the test run 12500: 9.775051124744376 %
# Accuracy of the network on the test run 12500: 9.771054783319705 %
# Accuracy of the network on the test run 12500: 9.787494891704128 %
# Accuracy of the network on the test run 12500: 9.783496732026144 %
# Accuracy of the network on the test run 12500: 9.789710085749286 %
# Accuracy of the network on the test run 12500: 9.785714285714286 %
# Accuracy of the network on the test run 12500: 9.791921664626683 %
# Accuracy of the network on the test run 12500: 9.787928221859707 %
# Accuracy of the network on the test run 12500: 9.783938035059112 %
# Accuracy of the network on the test run 12500: 9.7799511002445 %
# Accuracy of the network on the test run 12500: 9.786150712830958 %
# Accuracy of the network on the test run 12500: 9.792345276872965 %
# Accuracy of the network on the test run 12500: 9.7985347985348 %
# Accuracy of the network on the test run 12500: 9.804719283970709 %
# Accuracy of the network on the test run 12500: 9.800732004880032 %
# Accuracy of the network on the test run 12500: 9.796747967479675 %
# Accuracy of the network on the test run 12500: 9.79276716781796 %
# Accuracy of the network on the test run 12500: 9.788789601949635 %
# Accuracy of the network on the test run 12500: 9.784815265935851 %
# Accuracy of the network on the test run 12500: 9.79099025974026 %
# Accuracy of the network on the test run 12500: 9.787018255578094 %
# Accuracy of the network on the test run 12500: 9.783049472830495 %
# Accuracy of the network on the test run 12500: 9.79935143899473 %
# Accuracy of the network on the test run 12500: 9.795380875202593 %
# Accuracy of the network on the test run 12500: 9.791413527744027 %
# Accuracy of the network on the test run 12500: 9.787449392712551 %
# Accuracy of the network on the test run 12500: 9.783488466208013 %
# Accuracy of the network on the test run 12500: 9.77953074433657 %
# Accuracy of the network on the test run 12500: 9.78568540234533 %
# Accuracy of the network on the test run 12500: 9.781729991915926 %
# Accuracy of the network on the test run 12500: 9.777777777777779 %
# Accuracy of the network on the test run 12500: 9.783925686591276 %
# Accuracy of the network on the test run 12500: 9.779975777149778 %
# Accuracy of the network on the test run 12500: 9.786117836965294 %
# Accuracy of the network on the test run 12500: 9.782170229931424 %
# Accuracy of the network on the test run 12500: 9.778225806451612 %
# Accuracy of the network on the test run 12500: 9.77428456267634 %
# Accuracy of the network on the test run 12500: 9.770346494762288 %
# Accuracy of the network on the test run 12500: 9.766411598872331 %
# Accuracy of the network on the test run 12500: 9.772544283413849 %
# Accuracy of the network on the test run 12500: 9.778672032193159 %
# Accuracy of the network on the test run 12500: 9.774738535800482 %
# Accuracy of the network on the test run 12500: 9.780860474467229 %
# Accuracy of the network on the test run 12500: 9.786977491961414 %
# Accuracy of the network on the test run 12500: 9.803133788670149 %
# Accuracy of the network on the test run 12500: 9.799196787148594 %
# Accuracy of the network on the test run 12500: 9.805299076676034 %
# Accuracy of the network on the test run 12500: 9.801364365971107 %
# Accuracy of the network on the test run 12500: 9.797432811873245 %
# Accuracy of the network on the test run 12500: 9.793504410585404 %
# Accuracy of the network on the test run 12500: 9.799599198396793 %
# Accuracy of the network on the test run 12500: 9.795673076923077 %
# Accuracy of the network on the test run 12500: 9.801762114537445 %
# Accuracy of the network on the test run 12500: 9.807846277021618 %
# Accuracy of the network on the test run 12500: 9.823929571828732 %
# Accuracy of the network on the test run 12500: 9.83 %
# All recorded accuracies: [0.0, 0.0, 8.333333333333334, 12.5, 10.0, 8.333333333333334, 7.142857142857143, 6.25, 8.333333333333334, 7.5, 6.818181818181818, 6.25, 7.6923076923076925, 8.928571428571429, 8.333333333333334, 7.8125, 7.352941176470588, 6.944444444444445, 9.210526315789474, 10.0, 10.714285714285714, 11.363636363636363, 13.043478260869565, 13.541666666666666, 14.0, 14.423076923076923, 13.88888888888889, 14.285714285714286, 13.793103448275861, 13.333333333333334, 13.709677419354838, 14.0625, 13.636363636363637, 13.970588235294118, 13.571428571428571, 13.88888888888889, 14.18918918918919, 13.81578947368421, 14.102564102564102, 13.75, 13.414634146341463, 13.69047619047619, 13.372093023255815, 13.068181818181818, 12.777777777777779, 13.043478260869565, 12.76595744680851, 13.020833333333334, 12.755102040816327, 13.5, 13.235294117647058, 13.461538461538462, 13.20754716981132, 12.962962962962964, 12.727272727272727, 12.5, 12.280701754385966, 12.068965517241379, 11.864406779661017, 11.666666666666666, 11.475409836065573, 11.290322580645162, 11.11111111111111, 10.9375, 11.153846153846153, 11.363636363636363, 11.194029850746269, 11.029411764705882, 10.869565217391305, 10.714285714285714, 10.56338028169014, 10.416666666666666, 10.273972602739725, 10.135135135135135, 10.333333333333334, 10.197368421052632, 10.064935064935066, 9.935897435897436, 10.126582278481013, 10.0, 10.185185185185185, 10.060975609756097, 9.939759036144578, 9.821428571428571, 10.0, 9.883720930232558, 10.344827586206897, 10.511363636363637, 10.393258426966293, 10.277777777777779, 10.43956043956044, 10.326086956521738, 10.483870967741936, 10.372340425531915, 10.526315789473685, 10.677083333333334, 10.56701030927835, 10.714285714285714, 10.606060606060606, 10.75, 10.891089108910892, 11.27450980392157, 11.407766990291263, 11.298076923076923, 11.19047619047619, 11.556603773584905, 11.448598130841122, 11.342592592592593, 11.238532110091743, 11.363636363636363, 11.26126126126126, 11.160714285714286, 11.061946902654867, 10.964912280701755, 11.08695652173913, 10.991379310344827, 10.897435897435898, 10.805084745762711, 10.92436974789916, 10.833333333333334, 10.950413223140496, 10.860655737704919, 10.772357723577235, 11.088709677419354, 11.0, 10.912698412698413, 10.826771653543307, 10.7421875, 10.65891472868217, 10.961538461538462, 11.068702290076336, 11.363636363636363, 11.278195488721805, 11.380597014925373, 11.296296296296296, 11.213235294117647, 11.13138686131387, 11.231884057971014, 11.510791366906474, 11.428571428571429, 11.347517730496454, 11.267605633802816, 11.188811188811188, 11.11111111111111, 11.206896551724139, 11.13013698630137, 11.054421768707483, 11.14864864864865, 11.073825503355705, 11.0, 11.42384105960265, 11.348684210526315, 11.27450980392157, 11.525974025974026, 11.451612903225806, 11.378205128205128, 11.305732484076433, 11.234177215189874, 11.163522012578616, 11.40625, 11.490683229813664, 11.419753086419753, 11.503067484662576, 11.432926829268293, 11.363636363636363, 11.295180722891565, 11.22754491017964, 11.160714285714286, 11.094674556213018, 11.176470588235293, 11.257309941520468, 11.19186046511628, 11.127167630057803, 11.063218390804598, 11.142857142857142, 11.221590909090908, 11.158192090395481, 11.376404494382022, 11.452513966480447, 11.38888888888889, 11.32596685082873, 11.401098901098901, 11.475409836065573, 11.41304347826087, 11.35135135135135, 11.424731182795698, 11.363636363636363, 11.436170212765957, 11.375661375661375, 11.31578947368421, 11.256544502617801, 11.197916666666666, 11.139896373056995, 11.211340206185566, 11.282051282051283, 11.224489795918368, 11.16751269035533, 11.11111111111111, 11.055276381909549, 11.0, 10.945273631840797, 10.891089108910892, 10.83743842364532, 11.029411764705882, 11.097560975609756, 11.28640776699029, 11.231884057971014, 11.177884615384615, 11.124401913875598, 11.071428571428571, 11.018957345971565, 10.966981132075471, 10.915492957746478, 11.098130841121495, 11.162790697674419, 11.11111111111111, 11.05990 ...
