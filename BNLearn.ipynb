# %%
import bnlearn as bn
import pandas as pd
import numpy as np

# %%
df = bn.import_example('sprinkler')

# %%
df.head(10)
# Out:
#    Cloudy  Sprinkler  Rain  Wet_Grass
# 0       0          0     0          0
# 1       1          0     1          1
# 2       0          1     0          1
# 3       1          1     1          1
# 4       1          1     1          1
# 5       1          0     1          1
# 6       1          0     1          1
# 7       1          0     1          1
# 8       1          1     1          1
# 9       1          0     1          0

# %%
network = bn.structure_learning.fit(df, methodtype='hc', scoretype='bic')
bn.plot(network)
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# {'fig': <Figure size 1500x1000 with 1 Axes>,
#  'ax': <Figure size 1500x1000 with 1 Axes>,
#  'pos': {'Cloudy': array([-1.95872119e-16, -1.95872119e-16]),
#   'Sprinkler': array([-1., -1.]),
#   'Wet_Grass': array([3.25942837e-16, 3.25942837e-16]),
#   'Rain': array([1., 1.])},
#  'G': <networkx.classes.digraph.DiGraph at 0x15aa1d340>,
#  'node_properties': {'Cloudy': {'node_color': '#1f456e', 'node_size': 800},
#   'Sprinkler': {'node_color': '#1f456e', 'node_size': 800},
#   'Rain': {'node_color': '#1f456e', 'node_size': 800},
#   'Wet_Grass': {'node_color': '#1f456e', 'node_size': 800}},
#  'edge_properties': {('Cloudy', 'Sprinkler'): {'color': '#000000',
#    'weight': 1},
# ...
